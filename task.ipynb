# %%
df = pd.read_csv('iris.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv('iris.csv')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
df = pd.read_csv('iris.csv')

# %%
print(df)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
val = df[df['variety'] == 'Iris-setosa']

# %%
print(val)
# Out:
# Empty DataFrame
# Columns: [sepal.length, sepal.width, petal.length, petal.width, variety]
# Index: []

# %%
val = df[df['variety'] == 'iris-Setosa']

# %%
print(val)
# Out:
# Empty DataFrame
# Columns: [sepal.length, sepal.width, petal.length, petal.width, variety]
# Index: []

# %%
val = df[df['variety'] == 'Setosa' and df['sepal.width]>3.5]
# Out:
#   Cell In[12], line 1
#     val = df[df['variety'] == 'Setosa' and df['sepal.width]>3.5]
#                                                                 ^
# SyntaxError: EOL while scanning string literal

# %%
val = df[(df['variety'] == 'Setosa') & (df['sepal.width'] > 3.5)]

# %%
print(val)
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 4            5.0          3.6           1.4          0.2  Setosa
# 5            5.4          3.9           1.7          0.4  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa
# 14           5.8          4.0           1.2          0.2  Setosa
# 15           5.7          4.4           1.5          0.4  Setosa
# 16           5.4          3.9           1.3          0.4  Setosa
# 18           5.7          3.8           1.7          0.3  Setosa
# 19           5.1          3.8           1.5          0.3  Setosa
# 21           5.1          3.7           1.5          0.4  Setosa
# 22           4.6          3.6           1.0          0.2  Setosa
# 32           5.2          4.1           1.5          0.1  Setosa
# 33           5.5          4.2           1.4          0.2  Setosa
# 37           4.9          3.6           1.4          0.1  Setosa
# ...

# %%
val = df.rename(columns={'sepal.width': 'Sepal_Width'})

# %%
val
# Out:
#      sepal.length  Sepal_Width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df['SepalArea'] = df['sepal.length'] * df['Sepal_Width']

# %%
column_names = df.columns.tolist()

# %%
print(column_names)
# Out:
# ['sepal.length', 'Sepal_Width', 'petal.length', 'petal.width', 'variety', 'SepalArea']

# %%
val
# Out:
# 0      17.85
# 1      14.70
# 2      15.04
# 3      14.26
# 4      18.00
#        ...
# 145    20.10
# 146    15.75
# 147    19.50
# 148    21.08
# 149    17.70
# Length: 150, dtype: float64

# %%
df
# Out:
#      sepal.length  Sepal_Width  petal.length  petal.width    variety  \
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
#      SepalArea
# 0        17.85
# 1        14.70
# 2        15.04
# 3        14.26
# 4        18.00
# ..         ...
# 145      20.10
# ...

# %%
value = df.drop_duplicates(subset=['sepal.length', 'Sepal_Width', 'variety'], inplace=True)

# %%
value

# %%
print(value)
# Out:
# None

# %%
df
# Out:
#      sepal.length  Sepal_Width  petal.length  petal.width    variety  \
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 143           6.8          3.2           5.9          2.3  Virginica
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
#      SepalArea
# 0        17.85
# 1        14.70
# 2        15.04
# 3        14.26
# 4        18.00
# ..         ...
# 143      21.76
# ...

# %%
value = df.drop_duplicates(subset=[ 'variety'], inplace=True)

# %%
print(value)
# Out:
# None

# %%
df
# Out:
#      sepal.length  Sepal_Width  petal.length  petal.width     variety  \
# 0             5.1          3.5           1.4          0.2      Setosa
# 50            7.0          3.2           4.7          1.4  Versicolor
# 100           6.3          3.3           6.0          2.5   Virginica
#
#      SepalArea
# 0        17.85
# 50       22.40
# 100      20.79

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
values = df[df['variety'] == 'Setosa']

# %%
print(values)
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 0            5.1          3.5           1.4          0.2  Setosa
# 1            4.9          3.0           1.4          0.2  Setosa
# 2            4.7          3.2           1.3          0.2  Setosa
# 3            4.6          3.1           1.5          0.2  Setosa
# 4            5.0          3.6           1.4          0.2  Setosa
# 5            5.4          3.9           1.7          0.4  Setosa
# 6            4.6          3.4           1.4          0.3  Setosa
# 7            5.0          3.4           1.5          0.2  Setosa
# 8            4.4          2.9           1.4          0.2  Setosa
# 9            4.9          3.1           1.5          0.1  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa
# 12           4.8          3.0           1.4          0.1  Setosa
# ...

# %%
df['variety'] = df['variety'].replace('Setosa', 'Iris-setosa')

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width      variety
# 0             5.1          3.5           1.4          0.2  Iris-setosa
# 1             4.9          3.0           1.4          0.2  Iris-setosa
# 2             4.7          3.2           1.3          0.2  Iris-setosa
# 3             4.6          3.1           1.5          0.2  Iris-setosa
# 4             5.0          3.6           1.4          0.2  Iris-setosa
# ..            ...          ...           ...          ...          ...
# 145           6.7          3.0           5.2          2.3    Virginica
# 146           6.3          2.5           5.0          1.9    Virginica
# 147           6.5          3.0           5.2          2.0    Virginica
# 148           6.2          3.4           5.4          2.3    Virginica
# 149           5.9          3.0           5.1          1.8    Virginica
#
# [150 rows x 5 columns]

# %%
values = df[df['variety'] == 'Iris-setosa']

# %%
print(values)
# Out:
#     sepal.length  sepal.width  petal.length  petal.width      variety
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %%
df.to_csv('cleaned_iris.csv',index=False)

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width      variety
# 0             5.1          3.5           1.4          0.2  Iris-setosa
# 1             4.9          3.0           1.4          0.2  Iris-setosa
# 2             4.7          3.2           1.3          0.2  Iris-setosa
# 3             4.6          3.1           1.5          0.2  Iris-setosa
# 4             5.0          3.6           1.4          0.2  Iris-setosa
# ..            ...          ...           ...          ...          ...
# 145           6.7          3.0           5.2          2.3    Virginica
# 146           6.3          2.5           5.0          1.9    Virginica
# 147           6.5          3.0           5.2          2.0    Virginica
# 148           6.2          3.4           5.4          2.3    Virginica
# 149           5.9          3.0           5.1          1.8    Virginica
#
# [150 rows x 5 columns]

# %%
sort = df.sort_values(by='sepal.width', ascending=True)

# %%
print(sort)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width      variety
# 60            5.0          2.0           3.5          1.0   Versicolor
# 62            6.0          2.2           4.0          1.0   Versicolor
# 119           6.0          2.2           5.0          1.5    Virginica
# 68            6.2          2.2           4.5          1.5   Versicolor
# 41            4.5          2.3           1.3          0.3  Iris-setosa
# ..            ...          ...           ...          ...          ...
# 16            5.4          3.9           1.3          0.4  Iris-setosa
# 14            5.8          4.0           1.2          0.2  Iris-setosa
# 32            5.2          4.1           1.5          0.1  Iris-setosa
# 33            5.5          4.2           1.4          0.2  Iris-setosa
# 15            5.7          4.4           1.5          0.4  Iris-setosa
#
# [150 rows x 5 columns]

# %%
sort = df.sort_values(by='sepal.width', ascending=False)

# %%
print(sort)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width      variety
# 15            5.7          4.4           1.5          0.4  Iris-setosa
# 33            5.5          4.2           1.4          0.2  Iris-setosa
# 32            5.2          4.1           1.5          0.1  Iris-setosa
# 14            5.8          4.0           1.2          0.2  Iris-setosa
# 16            5.4          3.9           1.3          0.4  Iris-setosa
# ..            ...          ...           ...          ...          ...
# 87            6.3          2.3           4.4          1.3   Versicolor
# 62            6.0          2.2           4.0          1.0   Versicolor
# 68            6.2          2.2           4.5          1.5   Versicolor
# 119           6.0          2.2           5.0          1.5    Virginica
# 60            5.0          2.0           3.5          1.0   Versicolor
#
# [150 rows x 5 columns]

# %%
duplicate = df.duplicated()

# %%
print(duplicate)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
unique = df.drop_duplicates()

# %%
print(unique)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width      variety
# 0             5.1          3.5           1.4          0.2  Iris-setosa
# 1             4.9          3.0           1.4          0.2  Iris-setosa
# 2             4.7          3.2           1.3          0.2  Iris-setosa
# 3             4.6          3.1           1.5          0.2  Iris-setosa
# 4             5.0          3.6           1.4          0.2  Iris-setosa
# ..            ...          ...           ...          ...          ...
# 145           6.7          3.0           5.2          2.3    Virginica
# 146           6.3          2.5           5.0          1.9    Virginica
# 147           6.5          3.0           5.2          2.0    Virginica
# 148           6.2          3.4           5.4          2.3    Virginica
# 149           5.9          3.0           5.1          1.8    Virginica
#
# [149 rows x 5 columns]

# %%
from openpyxl import load_workbook

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the 'C:\Users\tarunkumar.s\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
wb = load_workbook('cleaned_iris.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 wb = load_workbook('cleaned_iris.xlsx')
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\openpyxl\reader\excel.py:346, in load_workbook(filename, read_only, keep_vba, data_only, keep_links, rich_text)
#     316 def load_workbook(filename, read_only=False, keep_vba=KEEP_VBA,
#     317                   data_only=False, keep_links=True, rich_text=False):
#     318     """Open the given filename and return the workbook
#     319
#     320     :param filename: the path to open or a file-like object
#    (...)
#     344
#     345     """
# --> 346     reader = ExcelReader(filename, read_only, keep_vba,
#     347                          data_only, keep_links, rich_text)
#     348     reader.read()
#     349     return reader.wb
#
# ...
